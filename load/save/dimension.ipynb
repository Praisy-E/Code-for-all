# %% [markdown]
# <a href="https://colab.research.google.com/github/Praisy-E/Code-for-all/blob/main/load/save/dimension.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
print(cv2.__version__)
# Out:
# 4.6.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img = cv2.imread('/rose.jpeg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1450 at 0x7FC0125FCAD0>

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg

# %%
plt.title("rose Image")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")
image = mpimg.imread("/rose.jpeg")
plt.imshow(image)
plt.show()

# %%
cv2.imwrite('output.jpg', image)
# Out:
# True

# %%
cv2.imwrite('output.png', image)
# Out:
# True

# %%
import numpy as np

print(image.shape)
# Out:
# (1450, 1000, 3)

# %%
image.shape[0]
# Out:
# 1450

# %%
print('Height of Image: {} pixels'.format(int(image.shape[0])))
print('Width of Image: {} pixels'.format(int(image.shape[1])))
print('Depth of Image: {} colors components'.format(int(image.shape[2])))
# Out:
# Height of Image: 1450 pixels
# Width of Image: 1000 pixels
# Depth of Image: 3 colors components
