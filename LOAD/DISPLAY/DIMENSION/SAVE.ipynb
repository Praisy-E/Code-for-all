# %% [markdown]
# <a href="https://colab.research.google.com/github/Praisy-E/Code-for-all/blob/main/LOAD/DISPLAY/DIMENSION/SAVE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Welcome to your first OpenCV Lesson. Here we'll learn to:
# 1. Import the OpenCV Model in Python
# 2. Load Images
# 3. Display Images
# 4. Save images
# 5. Getting the Image Dimension

# %%
# This is how we import OpenCV, we can't use OpenCV's functions without first doing this
import cv2

# %%
# Let's see what version we're running
print(cv2.__version__)
# Out:
# 4.6.0

# %%
# mount google drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load an image using 'imread' specifying the path to image
img = cv2.imread('/content/drive/MyDrive/download (1).jpg', cv2.IMREAD_UNCHANGED)

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg

# %%
plt.title("rose Image")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")
image = mpimg.imread("/content/drive/MyDrive/download (1).jpg")
plt.imshow(image)
plt.show()

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F720F9263D0>

# %% [markdown]
# **DISPLAYING IMGAES**

# %%
from matplotlib import pyplot as plt

#Show the image with matplotlib
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# Let's create a simple function to make displaying our images simpler and easier\

# %%
plt.title("Pedestrian Image")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")
image = mpimg.imread("/content/drive/MyDrive/download (1).jpg")
plt.imshow(image)
plt.show()

# %%
cv2.imwrite('output.jpg', image)
# Out:
# True

# %%
cv2.imwrite('output.png', image)
# Out:
# True

# %%
import numpy as np

print(image.shape)
# Out:
# (183, 275, 3)

# %%
image.shape[0]
# Out:
# 183

# %%
print('Height of Image: {} pixels'.format(int(image.shape[0])))
print('Width of Image: {} pixels'.format(int(image.shape[1])))
print('Depth of Image: {} colors components'.format(int(image.shape[2])))
# Out:
# Height of Image: 183 pixels
# Width of Image: 275 pixels
# Depth of Image: 3 colors components
